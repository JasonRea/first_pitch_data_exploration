# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/ninth_inning_first_pitch_data.csv")
df = df[df['pitches'] >= 5] # Include only pitchers who threw at least 5 pitches in the 9th inning

df.head()
# Out:
#    pitches  player_id       player_name  total_pitches  pitch_percent     ba  \
# 0       69     641941     Pagán, Emilio           1069            6.5  0.500
# 1       64     656546     Hoffman, Jeff           1132            5.7  0.429
# 2       63     663158    Suarez, Robert           1086            5.8  0.286
# 3       60     445276    Jansen, Kenley            878            6.8  0.250
# 4       59     628452  Iglesias, Raisel            974            6.1  0.100
#
#      iso  babip    slg   woba  ...  xslgdiff  wobadiff  swing_miss_percent  \
# 0  1.000  0.333  1.500  0.822  ...     0.577     0.318                23.8
# 1  0.429  0.333  0.857  0.543  ...    -0.356    -0.229                25.0
# 2  0.000  0.286  0.286  0.252  ...     0.012     0.029                31.6
# 3  0.000  0.250  0.250  0.221  ...     0.065     0.110                50.0
# 4  0.000  0.100  0.100  0.088  ...    -0.312    -0.199                15.0
#
# ...
